# %% [markdown]
# # Measured Skills
# ## I. Perform Operations using Data Types and Operators (20-25%)
# 1. Evaluate an expression to identify the data type Python will assign to each variable, including the following types: (**Unclear**)
#     1. str
#         * *get_type_of_item()*
#     1. int
#         * *get_type_of_item()*
#     1. float
#         * *get_type_of_item()*
#     1. bool
#         * *get_type_of_item()*
#     1. list
#         * *get_type_of_item()*
# 1. Perform data and data type operations, including the following:
#     1. convert from one data type to another
#         * *get_sum_and_num_of_chapters()*
#     1. construct data structures
#         * *get_book()*
#         * *get_sum_and_num_of_chapters()*
#         * *find_word()*
#         * *get_chapter_without_char()*
#     1. perform indexing and slicing operations ([ ] and [ : ])
#         * *green_glass_door()*
#         * *get_sum_and_num_of_chapters()*
# 1. Determine the sequence of execution based on operator precedence with the following operators:
#     1. assignment (=)
#         * green_glass_door(??)
#         * *import statements*
#         * *get_sum_and_num_of_chapters()*
#         * *word_finder()*
#         * *main()*
#     1. comparison (>, <, >=, <=, !=)
#     1. logical (and, or, not)
#         * *get_sum_and_num_of_chapters()*
#     1. arithmetic (+, -, *, /, **)
#         * *get_sum_and_num_of_chapters()*
#         * *word_finder()*
#     1. identity (is)
#     1. containment (in)
#         * *green_glass_door(?)*
#         * *main()*
#
# ## II. Control Flow with Decisions and Loops (25-30%)
# 1. Construct and analyze code segments that use branching statements including the following:
#     1. if
#         * *green_glass_door()*
#         * *get_sum_and_num_of_chapters()*
#         * *word_finder()*
#     1. if ... else
#     1. if ... elif ... else
#     1. nested conditional expressions
#         * *green_glass_door(?)*
#         * *get_sum_and_num_of_chapters()*
#         * *word_finder()*
#         * *main()*
#     1. compound conditional expressions
# 1. Construct and analyze code segments that perform iteration including the following statements:
#     1. while
#     1. for
#         * *green_glass_door()*
#         * *get_sum_and_num_of_chapters()*
#         * *word_finder()*
#         * *main()*
#     1. break
#     1. continue
#     1. pass
#     1. nested loops
#     1. loops that include compound conditional expressions
#
# ## III. Perform Input and Output Operations (20-25%)
# 1. Construct and analyze code segments that perform file input and output operations including the following:
#     1. open
#     1. close
#     1. read
#     1. write
#     1. append
#     1. check existance
#     1. delete
#     1. with statement
# 1. Construct and analyze code segments that perform console the following input and output operations:
#     1. read input from console
#     1. print formatted text
#     1. use command line arguments
#
# ## IV. Document and Structure Code (15-20%)
# 1. Properly format and document code using the following:
#     1. indentation
#         * *main()*
#     1. white space
#         * *main()*
#     1. comments
#     1. documentation strings (aka docstrings)
#     1. use pydoc to generate documentation
# 1. Construct and anaylize code segments that include the following function defintion constructs:
#     1. def statement
#         * *green_glass_door()*
#         * *get_sum_and_num_of_chapters()*
#         * *word_finder()*
#         * *main()*
#     1. return statement
#         * *green_glass_door()*
#         * *get_sum_and_num_of_chapters()*
#         * *word_finder()*
#         * *main()*
#     1. parameters and arguments
#         * *green_glass_door()*
#         * *word_finder()*
#     1. call signatures
#     1. default values
#
# ## V. Perform Troubleshooting and Error Handling (5-10%)
# 1. Analyze, detect, and fix code segments that have the following types of errors:
#     1. syntax errors
#     1. logic errors
#     1. runtime errors
# 1. Analyze and construct code segments that handle exceptions using the following:
#     1. try
#     1. except
#     1. else
#     1. finally
#     1. raise
#
# ## VI. Perform Operations Using Modules and Tools (1-5%)
# 1. Peform basic operations using the following built-in modules:
#     1. math
#     1. datetime
#     1. io
#     1. sys
#     1. os and os.path
#     1. random
# 1. Solve complex computing problems using the following built-in modules:
#     1. math
#     1. datetime
#     1. random
